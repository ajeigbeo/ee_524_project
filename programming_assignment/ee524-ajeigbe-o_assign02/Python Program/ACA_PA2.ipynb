# %%
#load required pacakages
import pandas as pd

# %%
#create empty dataframe
fl1 = pd.DataFrame()

f = open("./Data/401B.txt")
# print(f.read())

for i in range(20):
    benchmark = f.readline().split()[0]
    f.readline()
    l1d = f.readline().split()[1]
    l1i = f.readline().split()[1]
    l2s = f.readline().split()[1]
    l1a = f.readline().split()[1]
    l2a = f.readline().split()[1]
    f.readline()
    l2miss = f.readline().split()[1]
    icache = f.readline().split()[1]
    dcache = f.readline().split()[1]    
    f.readline()


    tempdf = pd.DataFrame()
    tempdf['BenchMark'] = [benchmark]
    tempdf['l1d'] = [l1d]
    tempdf['l1i'] = [l1i]
    tempdf['l2s'] = [l2s]
    tempdf['l1a'] = [l1a]
    tempdf['l2a'] = [l2a]
    tempdf['l2miss'] = [l2miss]
    tempdf['icache'] = [icache]
    tempdf['dcache'] = [dcache]
    tempdf['filename'] = tfile

    fl1 = pd.concat([fl1, tempdf], ignore_index = True)
    # print(benchmark)
    # print(l1d)
    # print(l1i)
    # print(l2s)
    # print(l1a)
    # print(l2a)
    # print(l2miss)
    # print(icache)
    # print(dcache)

# %%
fl1
# Out:
#     BenchMark    l1d    l1i  l2s l1a l2a    l2miss    icache    dcache  \
# 0   401.bzip2  128kB   64kB  1MB   2   4  0.659358  0.000001  0.013116
# 1   401.bzip2  128kB   64kB  2MB   2   4  0.580602  0.000001  0.013116
# 2   401.bzip2  128kB   64kB  4MB   2   4  0.543582  0.000001  0.013116
# 3   401.bzip2  256kB   64kB  1MB   2   4  0.749346  0.000001  0.011544
# 4   401.bzip2  256kB   64kB  2MB   2   4  0.659649  0.000001  0.011544
# 5   401.bzip2  256kB   64kB  4MB   2   4  0.617593  0.000001  0.011544
# 6   401.bzip2  128kB  128kB  1MB   2   4  0.659356  0.000001  0.013116
# 7   401.bzip2  128kB  128kB  2MB   2   4  0.580591  0.000001  0.013116
# 8   401.bzip2  128kB  128kB  4MB   2   4  0.543571  0.000001  0.013116
# 9   401.bzip2  256kB  128kB  1MB   2   4  0.749345  0.000001  0.011544
# 10  401.bzip2  256kB  128kB  2MB   2   4  0.659638  0.000001  0.011544
# 11  401.bzip2  256kB  128kB  4MB   2   4  0.617580  0.000001  0.011544
# ...

# %%
# #create empty dataframe
# fl1 = pd.DataFrame()

# # imports data
# # file1 = "./Data/401B.txt"
# file2 = "./Data/429B.txt"
# file3 = "./Data/456B.txt"
# file4 = "./Data/458B.txt"
# file5 = "./Data/470B.txt"
# # files = "~/Users/oluwafemiajeigbe/Documents/Courses/Advanced Computer Architecture/HW/Fall 2022/PA/PA2/Data"

# files = file2, file3, file4, file5
# for tfile in files:

#     with open(tfile) as f:

#         for i in range(14):
#             benchmark = f.readline().split()[9]
#             f.readline()
#             l1d = f.readline().split()[1]
#             l1i = f.readline().split()[1]
#             l2s = f.readline().split()[1]
#             l1a = f.readline().split()[1]
#             l2a = f.readline().split()[1]
#             f.readline()
#             l2miss = f.readline().split()[1]
#             icache = f.readline().split()[1]
#             dcache = f.readline().split()[1]
#             f.readline()

#             tempdf = pd.DataFrame()
#             tempdf['BenchMark'] = [benchmark]
#             tempdf['l1d'] = [l1d]
#             tempdf['l1i'] = [l1i]
#             tempdf['l2s'] = [l2s]
#             tempdf['l1a'] = [l1a]
#             tempdf['l2a'] = [l2a]
#             tempdf['l2miss'] = [l2miss]
#             tempdf['icache'] = [icache]
#             tempdf['dcache'] = [dcache]
#             tempdf['filename'] = tfile

#             fl1 = pd.concat([fl1, tempdf], ignore_index = True)
